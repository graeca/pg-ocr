# %%
# %%bash
# sh countwords.sh 'πνεῦμα'
# echo "======================"
# sh countwords.sh 'κύριος'
# Out:
# Couldn't find program: 'bash'

# %%
# %%bash
# words='∆αυῒδ
# Ῥωμαίοις
# ὑποστάσεως
# πίστεως
# ἅγιον
# Κορινθίοις
# φῶς
# Ἰησοῦ
# Χριστοῦ
# Παῦλος
# πατρὸς
# υἱὸς
# θεὸν
# κύριος
# πνεύματος
# πνεῦμα
# θεὸς
# ὅτι
# γὰρ
# καὶ'
#
# #echo $words
#
# for word in `echo "$words"`
# do
# echo $word
# echo '-------------------------'
# sh countwords.sh "$word"
# done
# Out:
# ∆αυῒδ Ῥωμαίοις ὑποστάσεως πίστεως ἅγιον Κορινθίοις φῶς Ἰησοῦ Χριστοῦ Παῦλος πατρὸς υἱὸς θεὸν κύριος πνεύματος πνεῦμα θεὸς ὅτι γὰρ καὶ
# ∆αυῒδ
# -------------------------
#       9 ∆αυῒδ
# Ῥωμαίοις
# -------------------------
#       6 Ῥωμαίοις
#       2 Ῥωμαίοις·
# ὑποστάσεως
# -------------------------
#      11 ὑποστάσεως
#       1 ὑποστάσεως.
#       1 ὑποστάσεως»
#       1 ὑποστάσεως».
# πίστεως
# -------------------------
#       5 πίστεως
# ἅγιον
# -------------------------
#      15 ἅγιον
#       1 ἅγιον»
#       1 ἅγιον»,
#       3 ἅγιον·
# Κορινθίοις
# -------------------------
#      14 Κορινθίοις
#       1 Κορινθίοις,
#       4 Κορινθίοις·
# φῶς
# -------------------------
#       3 σαφῶς
#       1 σαφῶς,
#      16 φῶς
#       4 φῶς,
#       1 φῶς».
# Ἰησοῦ
# -------------------------
#      15 Ἰησοῦ
#       2 Ἰησοῦν
#       5 Ἰησοῦς
#       1 Ἰησοῦς»
# Χριστοῦ
# -------------------------
#      13 Χριστοῦ
#       2 Χριστοῦ,
#       1 Χριστοῦ»,
#       5 Χριστοῦ».
# ...
