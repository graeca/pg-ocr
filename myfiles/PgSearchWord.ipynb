# %%
import cv2 as cv2  
from matplotlib import pyplot as plt
import numpy as np
import re

import shutil
import glob, os

# %run PgFunctions.py 




#f=open("results/results.html", "w")
#f.write('')
#f.close()

wordlinks=[]
#for filename in glob.glob("source/*pdf300.png"):
for filename in glob.glob("source/0177.pdf300.png"):
#for filename in glob.glob("source/0194.pdf300.png"):    
    print(filename)
    filename_w_ext = os.path.basename(filename)
    name, extension = os.path.splitext(filename_w_ext)
    print(name)
    folder=name
    
   
    query= cv2.imread("word/fos.png",0);
    
    query= cv2.imread("word/kyrios2.png",0);
    query= cv2.imread("word/kyrios.png",0);
    #erodeQuery=applyCircleErosion(query)
    ###plt.figure()
    ###plt.imshow(erodeQuery)
    x=searchData(query,folder)
    for val in x:
        
        wordlinks.append(val)
    
    
print(wordlinks)
print(len(wordlinks))

with open("searchResults.txt", 'w') as f:
    for wordlink in wordlinks:
        f.write(str(wordlink) + '\n')
# Out:
# source/0177.pdf300.png
# 0177.pdf300
# test/0177.pdf300\1480-1230-116-38.png
# ContoursNum: 2
# ShapeMatch: 0.04377541862793807
# Area: 3336.5
# Context: 0.019574902951717377
# Width: 116
# ====================
# test/0177.pdf300\1481-1104-119-36.png
# ContoursNum: 2
# ShapeMatch: 0.02860986061888227
# Area: 3353.5
# Context: 0.021985948085784912
# Width: 119
# ====================
# test/0177.pdf300\1528-1784-120-35.png
# ContoursNum: 2
# ShapeMatch: 0.04744992946760847
# Area: 3382.0
# Context: 0.020309893414378166
# Width: 120
# ====================
# test/0177.pdf300\1573-1105-117-35.png
# ContoursNum: 3
# ShapeMatch: 0.011119548006785808
# Area: 3301.0
# Context: 0.01660904288291931
# Width: 117
# ====================
# test/0177.pdf300\198-1193-116-35.png
# ContoursNum: 2
# ShapeMatch: 0.007414510592282148
# Area: 3334.5
# Context: 0.01533515378832817
# Width: 116
# ====================
# test/0177.pdf300\243-1594-117-36.png
# ContoursNum: 3
# ShapeMatch: 0.014332121396802245
# Area: 3265.5
# Context: 0.014233763329684734
# Width: 117
# ====================
# test/0177.pdf300\290-1285-128-36.png
# ContoursNum: 2
# ShapeMatch: 0.02104644373279654
# Area: 3303.0
# Context: 0.025630122050642967
# Width: 118
# ====================
# test/0177.pdf300\795-1593-126-35.png
# ContoursNum: 2
# ShapeMatch: 0.024506661517888884
# Area: 3276.5
# Context: 0.02381313592195511
# Width: 116
# ====================
# test/0177.pdf300\841-1420-119-34.png
# ContoursNum: 3
# ShapeMatch: 0.020502180812344558
# Area: 3336.5
# Context: 0.01811136305332184
# Width: 119
# ====================
# test/0177.pdf300\887-1635-116-35.png
# ContoursNum: 3
# ShapeMatch: 0.016822304053188547
# Area: 3300.5
# Context: 0.02547347918152809
# Width: 116
# ====================
# test/0177.pdf300\979-1783-123-35.png
# ContoursNum: 2
# ShapeMatch: 0.04901675009111948
# Area: 3419.0
# Context: 0.03204156830906868
# Width: 123
# ====================
# 11
# [WindowsPath('test/0177.pdf300/1480-1230-116-38.png'), WindowsPath('test/0177.pdf300/1481-1104-119-36.png'), WindowsPath('test/0177.pdf300/1528-1784-120-35.png'), WindowsPath('test/0177.pdf300/1573-1105-117-35.png'), WindowsPath('test/0177.pdf300/198-1193-116-35.png'), WindowsPath('test/0177.pdf300/243-1594-117-36.png'), WindowsPath('test/0177.pdf300/290-1285-128-36.png'), WindowsPath('test/0177.pdf300/795-1593-126-35.png'), WindowsPath('test/0177.pdf300/841-1420-119-34.png'), WindowsPath('test/0177.pdf300/887-1635-116-35.png'), WindowsPath('test/0177.pdf300/979-1783-123-35.png')]
# 11
