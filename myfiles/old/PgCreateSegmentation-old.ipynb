# %%
import cv2 as cv2  
from matplotlib import pyplot as plt
import numpy as np

from PgFunctions import clearBorder
from PgFunctions import checkDiacritics
from PgFunctions import cutPunctuation
from PgFunctions import applyCircleErosion
from PgFunctions import applyWordSegmentation
from PgFunctions import searchData
from PgFunctions import createView

import shutil
import glob, os


for filename in glob.glob("source/*pdf300.png"):
    print(filename)
    filename_w_ext = os.path.basename(filename)
    name, extension = os.path.splitext(filename_w_ext)
    print(name)
    folder=name
    
    if os.path.exists('test/'+folder):    
        shutil.rmtree('test/'+folder)
        
    os.mkdir('test/'+folder)
    img = cv2.imread(filename,0)
    applyWordSegmentation(img,folder)
# Out:
# source/0159.pdf300.png
# 0159.pdf300
# source/0195.pdf300.png
# 0195.pdf300
# source/0190.pdf300.png
# 0190.pdf300
# source/0151.pdf300.png
# 0151.pdf300
# source/0157.pdf300.png
# 0157.pdf300
# source/0176.pdf300.png
# 0176.pdf300
# source/0156.pdf300.png
# 0156.pdf300
# source/0185.pdf300.png
# 0185.pdf300
# source/0161.pdf300.png
# 0161.pdf300
# source/0193.pdf300.png
# 0193.pdf300
# source/0152.pdf300.png
# 0152.pdf300
# source/0178.pdf300.png
# 0178.pdf300
# source/0189.pdf300.png
# 0189.pdf300
# source/0192.pdf300.png
# 0192.pdf300
# source/0180.pdf300.png
# 0180.pdf300
# source/0183.pdf300.png
# 0183.pdf300
# source/0154.pdf300.png
# 0154.pdf300
# source/0184.pdf300.png
# 0184.pdf300
# source/0158.pdf300.png
# 0158.pdf300
# source/0191.pdf300.png
# 0191.pdf300
# source/0196.pdf300.png
# 0196.pdf300
# source/0163.pdf300.png
# 0163.pdf300
# source/0167.pdf300.png
# 0167.pdf300
# source/0153.pdf300.png
# 0153.pdf300
# source/0162.pdf300.png
# 0162.pdf300
# source/0169.pdf300.png
# 0169.pdf300
# source/0186.pdf300.png
# 0186.pdf300
# source/0168.pdf300.png
# 0168.pdf300
# source/0174.pdf300.png
# 0174.pdf300
# source/0181.pdf300.png
# 0181.pdf300
# source/0160.pdf300.png
# 0160.pdf300
# source/0155.pdf300.png
# 0155.pdf300
# source/0172.pdf300.png
# 0172.pdf300
# source/0194.pdf300.png
# 0194.pdf300
# source/0177.pdf300.png
# 0177.pdf300
# source/0165.pdf300.png
# 0165.pdf300
# source/0164.pdf300.png
# 0164.pdf300
# source/0173.pdf300.png
# 0173.pdf300
# source/0187.pdf300.png
# 0187.pdf300
# source/0175.pdf300.png
# 0175.pdf300
# source/0188.pdf300.png
# 0188.pdf300
# source/0179.pdf300.png
# 0179.pdf300
# source/0166.pdf300.png
# 0166.pdf300
# source/0171.pdf300.png
# 0171.pdf300
