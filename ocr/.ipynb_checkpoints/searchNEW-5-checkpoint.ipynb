# %%
import cv2 as cv2  
from matplotlib import pyplot as plt
import numpy as np
import re
from  PgFunctions import *
import shutil
import glob, os

# %run PgFunctions.py 
ip=!wget -qO - ipv4bot.whatismyipaddress.com
def compareHUandSC(queryFile, dataFile):
        
        params={}
        
        query= cv2.imread(queryFile,0);
        erodeimg=applyCircleErosion(query)
        _, QueryContours, _ = cv2.findContours(erodeimg, cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE) 
        
        
        data = cv2.imread(filename,0)

        if data is None:
            params["DA"]="NONE"
            return params
        else:
            params["DA"]="EXIST"
            erodedata=applyCircleErosion(data)
            _, DataContours, _ = cv2.findContours(erodedata, cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE) 
        
        
        
        if len(DataContours)>1:
            params["CO"]="EXIST"
           
            
            
            #cut off the very disimilar images using HU moments for speeding the algorithm
            ret = cv2.matchShapes(QueryContours[1],DataContours[1],3,0.0)
            params["HU"]=ret
            if ret<0.1:
                sd = cv2.createShapeContextDistanceExtractor()
                try:
                    abc = sd.computeDistance(QueryContours[1],DataContours[1])
                    params["SC-CM"]="EXIST"
                    params["SC"]=abc    
                    (x, y, w, h) = cv2.boundingRect(DataContours[1])   
                    OSfilename=Path(filename)
                    params["PA"]=OSfilename
                   
                except:
                    params["SC-CM"]="NONE" 
                    (x, y, w, h) = cv2.boundingRect(DataContours[1])
                    OSfilename=Path(filename)
                    params["PA"]=OSfilename
            #return
        else:
                params["CO"]="NONE"
                #print(filename)
                #x=0
        return params 
            
            
#END FUNCTION            
            
            
     
    
    
    
    
    
    
    
    
            
            
            



#query= cv2.imread("word/fos.png",0);
#query= cv2.imread("word/kyrios2.png",0);
#query= cv2.imread("word/kyrios.png",0);





queryFile= "word/kyrios.png"
wordtokens=!find word -type f -name *.png| sed -n /ipynb/!p

for queryFile in wordtokens:
    print(queryFile)
    
    wordlinks=[]
    #for filename in glob.glob("source/*pdf300.png"):
    for filename in glob.glob("source/0194.pdf300.png"):
    #for filename in glob.glob("source/0189.pdf300.png"):    
        print(filename)
        filename_w_ext = os.path.basename(filename)
        name, extension = os.path.splitext(filename_w_ext)
        print(name)
        folder=name



        #erode query


        count=0


        content=''

        for filename in glob.glob("test/"+folder+"/*.png"):


            filename_w_ext = os.path.basename(filename)
            name, extension = os.path.splitext(filename_w_ext)

            coords=name.split("-")





            #break
            #queryFile= "word/pneuma.png"



            dataFile=filename
            results=compareHUandSC(queryFile, dataFile)
            #print(results)
            if "SC" in results:
                if results["SC"]<0.06:
                    wordlinks.append(results["PA"])
                    divB='<div style="'+'position: absolute;top: '+coords[0]+'px;left:'+coords[1]+'px;border: 3px solid red;position: absolute;">'
                    divE='</div>'
                    imgtag=divB+'<img src="../'+ filename +'">'+divE
                    content=content+imgtag
                    f=results["PA"]
                    print(results["PA"])
                    print(results["SC"])


                    #print(ip[0])
                    #fig=plt.figure()
                    #fig.text(.05,.05,results["PA"])
                    #img= cv2.imread(filename,0);
                    #plt.imshow(img)




                else:
                    divB='<div style="'+'position: absolute;top: '+coords[0]+'px;left:'+coords[1]+'px;border: 1px solid blue;position: absolute;">'
                    divE='</div>'
                    imgtag=divB+'<img src="../'+ filename +'">'+divE
                    content=content+imgtag
            else:
                divB='<div style="'+'position: absolute;top: '+coords[0]+'px;left:'+coords[1]+'px;border: 1px solid blue;position: absolute;">'
                divE='</div>'
                imgtag=divB+'<img src="../'+ filename +'">'+divE
                content=content+imgtag


        #create page from segment words
        resFile='resultsSpot/'+folder+'.html'
        # !echo > {resFile}
        f = open(resFile, "w")
        f.write(content)
        f.close()



    #create page with founded words
    queryHtml=queryFile+'.html'
    # !rm {queryHtml}
    # !echo > {queryHtml}
    print(wordlinks)    
    with open(queryHtml, 'w') as f:
        for item in wordlinks:
            wordtag='<img src="../'+ str(item) +'">'
            f.write("%s\n" % wordtag)
# Out:
# word/gar.png
# source/0194.pdf300.png
# 0194.pdf300
# test/0194.pdf300/1091-282-64-37.png
# 0.018132297322154045
# test/0194.pdf300/1227-443-64-37.png
# 0.0205062385648489
# [PosixPath('test/0194.pdf300/1091-282-64-37.png'), PosixPath('test/0194.pdf300/1227-443-64-37.png')]
# word/Ihsou.png
# source/0194.pdf300.png
# 0194.pdf300
# test/0194.pdf300/2065-906-111-35.png
# 0.017777496948838234
# test/0194.pdf300/2109-905-112-36.png
# 0.01947043277323246
# [PosixPath('test/0194.pdf300/2065-906-111-35.png'), PosixPath('test/0194.pdf300/2109-905-112-36.png')]
# word/fos.png
# source/0194.pdf300.png
# 0194.pdf300
# []
# word/Yios.png
# source/0194.pdf300.png
# 0194.pdf300
# []
# word/pneumatos.png
# source/0194.pdf300.png
# 0194.pdf300
# test/0194.pdf300/1878-402-168-37.png
# 0.027623573318123817
# test/0194.pdf300/1740-256-181-37.png
# 0.04364995285868645
# [PosixPath('test/0194.pdf300/1878-402-168-37.png'), PosixPath('test/0194.pdf300/1740-256-181-37.png')]
# word/paulos.png
# source/0194.pdf300.png
# 0194.pdf300
# test/0194.pdf300/729-742-114-36.png
# 0.023788947612047195
# test/0194.pdf300/2017-601-116-35.png
# 0.026234881952404976
# test/0194.pdf300/498-300-124-35.png
# 0.025511102750897408
# [PosixPath('test/0194.pdf300/729-742-114-36.png'), PosixPath('test/0194.pdf300/2017-601-116-35.png'), PosixPath('test/0194.pdf300/498-300-124-35.png')]
# word/ypostateos.png
# source/0194.pdf300.png
# 0194.pdf300
# []
# word/agion.png
# source/0194.pdf300.png
# 0194.pdf300
# []
# word/oti.png
# source/0194.pdf300.png
# 0194.pdf300
# test/0194.pdf300/2245-1801-55-28.png
# 0.04215942695736885
# test/0194.pdf300/911-902-55-30.png
# 0.03254750743508339
# test/0194.pdf300/1096-965-54-29.png
# 0.02513696439564228
# test/0194.pdf300/2329-220-52-20.png
# 0.03129135072231293
# test/0194.pdf300/860-225-56-29.png
# 0.031040621921420097
# test/0194.pdf300/860-286-59-30.png
# 0.05136895552277565
# rm: cannot remove 'word/oti.png.html': No such file or directory
# [PosixPath('test/0194.pdf300/2245-1801-55-28.png'), PosixPath('test/0194.pdf300/911-902-55-30.png'), PosixPath('test/0194.pdf300/1096-965-54-29.png'), PosixPath('test/0194.pdf300/2329-220-52-20.png'), PosixPath('test/0194.pdf300/860-225-56-29.png'), PosixPath('test/0194.pdf300/860-286-59-30.png')]
# word/kyrios.png
# source/0194.pdf300.png
# 0194.pdf300
# test/0194.pdf300/2419-1302-109-36.png
# 0.052859675139188766
# test/0194.pdf300/953-578-119-38.png
# 0.05984792485833168
# rm: cannot remove 'word/kyrios.png.html': No such file or directory
# [PosixPath('test/0194.pdf300/2419-1302-109-36.png'), PosixPath('test/0194.pdf300/953-578-119-38.png')]
# word/pneuma.png
# source/0194.pdf300.png
# 0194.pdf300
# rm: cannot remove 'word/pneuma.png.html': No such file or directory
# []
# word/patir.png
# source/0194.pdf300.png
# 0194.pdf300
# rm: cannot remove 'word/patir.png.html': No such file or directory
# []
# word/xristou.png
# source/0194.pdf300.png
# 0194.pdf300
# rm: cannot remove 'word/xristou.png.html': No such file or directory
# []
# word/pisteos.png
# source/0194.pdf300.png
# 0194.pdf300
# rm: cannot remove 'word/pisteos.png.html': No such file or directory
# []
# word/kai.png
# source/0194.pdf300.png
# 0194.pdf300
# test/0194.pdf300/1277-963-55-28.png
# 0.03011620230972767
# test/0194.pdf300/1093-567-60-29.png
# 0.043415699154138565
# test/0194.pdf300/364-227-59-29.png
# 0.046862419694662094
# test/0194.pdf300/2528-222-58-29.png
# 0.027339735999703407
# test/0194.pdf300/2876-338-67-37.png
# 0.03490369766950607
# test/0194.pdf300/1001-494-58-28.png
# 0.030119454488158226
# test/0194.pdf300/634-348-60-30.png
# 0.05524781346321106
# test/0194.pdf300/1320-572-59-29.png
# 0.04474688321352005
# test/0194.pdf300/1786-482-57-29.png
# 0.030139591544866562
# test/0194.pdf300/1970-434-60-30.png
# 0.04481340944766998
# rm: cannot remove 'word/kai.png.html': No such file or directory
# [PosixPath('test/0194.pdf300/1277-963-55-28.png'), PosixPath('test/0194.pdf300/1093-567-60-29.png'), PosixPath('test/0194.pdf300/364-227-59-29.png'), PosixPath('test/0194.pdf300/2528-222-58-29.png'), PosixPath('test/0194.pdf300/2876-338-67-37.png'), PosixPath('test/0194.pdf300/1001-494-58-28.png'), PosixPath('test/0194.pdf300/634-348-60-30.png'), PosixPath('test/0194.pdf300/1320-572-59-29.png'), PosixPath('test/0194.pdf300/1786-482-57-29.png'), PosixPath('test/0194.pdf300/1970-434-60-30.png')]
# word/patros.png
# source/0194.pdf300.png
# 0194.pdf300
# test/0194.pdf300/1705-315-125-38.png
# 0.025927996262907982
# test/0194.pdf300/1833-518-127-37.png
# 0.0182575061917305
# rm: cannot remove 'word/patros.png.html': No such file or directory
# [PosixPath('test/0194.pdf300/1705-315-125-38.png'), PosixPath('test/0194.pdf300/1833-518-127-37.png')]
# word/dauid.png
# source/0194.pdf300.png
# 0194.pdf300
# rm: cannot remove 'word/dauid.png.html': No such file or directory
# []
