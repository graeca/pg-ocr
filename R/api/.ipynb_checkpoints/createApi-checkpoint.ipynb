# %%
from itertools import groupby
import numpy as np
import json
filename='api/pg/author1/work2.txt'
 
s='ddd ggg'
s.split( ' ')
#words=words_all
#abc =sorted(set(abc))
#words_counts = [(word, len(list(c))) for word,c in groupby(sorted(words ))]
#print(words_counts)
#a=np.char.split('f ty ')
#a = ['dd','1w', 'w0',' 2', '1', 0, 3, 3]

###############################

words_all=[]
fragmentfiles=!find api/fragments -type f|sort
for fragmentfile in fragmentfiles:
    #print(fragmentfile)
    lines_in_file = open(filename).read().splitlines()
    words_in_file = [(word) for line in lines_in_file for word in line.split(' ') ]
    words_all=words_all+words_in_file

words_alls=np.array(words_all)
words_uniq, counts = np.unique(words_all, return_counts=True)  # array([0, 1, 2, 3]), array([2, 3, 1, 2]
str_counts=[str(num) for num in counts]
words_dict=dict(zip(words_uniq, str_counts))  # {0: 2, 1: 3, 2: 1, 3: 2}


#with open('elements.json', 'a', encoding="utf-8") as file:
#x = json.dumps(words_dict, indent=4)
    #file.write(x + '\n')
    
#json.dump(data, f)

with open('api/file.json', 'w') as f:
    #data['new_key'] = [1, 2, 3]
    json.dump(words_dict, f)
    x=0
    
print(words_dict)
# Out:
# {'': '16', '197': '8', '2': '8', '3': '16', '4': '24', '5': '8', '6': '8', 'Historiae': '8', 'Α': '8', 'ΑΓΑΘΙΟΥ': '8', 'Βυζάντιον': '8', 'Γετικὴ': '8', 'Ζαμόλξιδος': '8', 'ΙΣΤΟΡΙΩΝ': '8', 'Καλὸν': '8', 'Νεμεονῖκαι': '8', 'Οὐννικὰ': '8', 'ΠΡΟΟΙΜΙΟΝ': '8', 'ΣΧΟΛΑΣΤΙΚΟΥ': '8', 'αἱ': '16', 'αὐτοὺς': '24', 'αὐτοῖς': '24', 'αὐτὴν': '16', 'αὐτὸς': '8', 'αὐτῶν': '16', 'αὖ': '8', 'βαρβάρων': '8', 'βασιλέως': '8', 'βεβαίας': '8', 'βίον': '8', 'βίῳ': '8', 'γαστα': '8', 'γε': '24', 'γεγένηνται,': '8', 'γενοῖν': '8', 'γενόμενοι': '8', 'γνώμῃ': '8', 'γνῶσις': '8', 'γυμνὴ': '8', 'γὰρ': '32', 'γῆς': '8', 'δεινοῖς': '8', 'διαβιώσκειν.': '8', 'διαδηλοτάτη': '8', 'διαδιδράσκει': '8', 'διαρρυεῖσαι': '8', 'διαρρυήσεται,': '8', 'διαφανῆ': '8', 'διαφθειρομένων': '8', 'διενοοῦντο·': '8', 'διεξιέναι': '8', 'διετέλουν': '8', 'δουλεύειν': '8', 'δράσαιεν,': '8', 'δυνάμεις': '8', 'δυσμένειαν': '8', 'δὲ': '56', 'δὴ': '16', 'δή': '8', 'δήπου': '8', 'δόξαν': '8', 'δόξης': '8', 'δύναται': '8', 'εἰ': '24', 'εἰδότες,': '8', 'εἰπεῖν,': '8', 'εἰρήσεται': '8', 'εἴη': '8', 'εἴπερ': '8', 'εὐβουλία,': '8', 'εὔδαιμον': '8', 'εὖ': '8', 'θεία': '8', 'θείῳ': '8', 'θνητὰ': '8', 'καθίσταντο·': '8', 'καρπώσασθαι': '8', "κατ'": '8', 'κατὰ': '24', 'κατάλυσις': '8', 'καὶ': '304', 'καί': '8', 'κερδαλέου': '8', 'κινῶν': '8', 'κλέος': '8', 'κονίστραις': '8', 'κοτίνου': '8', 'κτησαμένοις': '8', 'κίνδυνον': '8', 'λαφύρων': '8', 'λεηλασίας': '8', 'λείαν': '8', 'λησι': '8', 'λήθη': '8', 'μακρῷ': '8', 'μεγάλα': '8', 'μειονεκτεῖσθαι,': '8', 'μεμένηκε': '8', 'μεταβεβλῆσθαι.': '8', 'μετῆλθον': '8', 'μνήμη': '8', 'μοι': '8', 'μάλα': '16', 'μάχην': '8', 'μὲν': '24', 'μέγιστα': '8', 'μέν': '16', 'μ