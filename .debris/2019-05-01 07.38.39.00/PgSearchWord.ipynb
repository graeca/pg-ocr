# %%
import cv2 as cv2  
from matplotlib import pyplot as plt
import numpy as np
import re



# %run PgFunctions.py 


import shutil
import glob, os

f=open("results/results.html", "w")
f.write('')
f.close()
wordlinks=[]
#for filename in glob.glob("source/*pdf300.png"):
for filename in glob.glob("source/0177.pdf300.png"):
#for filename in glob.glob("source/0194.pdf300.png"):    
    print(filename)
    filename_w_ext = os.path.basename(filename)
    name, extension = os.path.splitext(filename_w_ext)
    print(name)
    folder=name
    
   
    query= cv2.imread("word/fos.png",0);
    query= cv2.imread("word/kyrios.png",0);
    query= cv2.imread("word/kyrios2.png",0);
    #erodeQuery=applyCircleErosion(query)
    ###plt.figure()
    ###plt.imshow(erodeQuery)
    x=searchData(query,folder)
    for val in x:
        
        wordlinks.append(val)
    
    
print(wordlinks)
print(len(wordlinks))

with open("searchResults.txt", 'w') as f:
    for wordlink in wordlinks:
        f.write(str(wordlink) + '\n')
# Out:
# source/0177.pdf300.png
# 0177.pdf300
# test/0177.pdf300\1481-1104-119-36.png
# ContoursNum: 2
# ShapeMatch: 0.08286909725308596
# Area: 3353.5
# Context: 0.056543782353401184
# Width: 119
# ====================
# test/0177.pdf300\1856-1602-122-36.png
# ContoursNum: 2
# ShapeMatch: 0.0
# Area: 3284.0
# Context: 0.0035643407609313726
# Width: 112
# ====================
# test/0177.pdf300\1926-1108-123-37.png
# ContoursNum: 2
# ShapeMatch: 0.032133396919193515
# Area: 3215.0
# Context: 0.018148206174373627
# Width: 112
# ====================
# test/0177.pdf300\2839-608-113-37.png
# ContoursNum: 2
# ShapeMatch: 0.035609805886138116
# Area: 3252.0
# Context: 0.017955895513296127
# Width: 113
# ====================
# test/0177.pdf300\2872-476-126-38.png
# ContoursNum: 2
# ShapeMatch: 0.013304316467372635
# Area: 3358.0
# Context: 0.017506150528788567
# Width: 112
# ====================
# test/0177.pdf300\290-1285-128-36.png
# ContoursNum: 2
# ShapeMatch: 0.08014253317308455
# Area: 3303.0
# Context: 0.05758054554462433
# Width: 118
# ====================
# test/0177.pdf300\795-1593-126-35.png
# ContoursNum: 2
# ShapeMatch: 0.06127373114413902
# Area: 3276.5
# Context: 0.054037436842918396
# Width: 116
# ====================
# test/0177.pdf300\887-1635-116-35.png
# ContoursNum: 3
# ShapeMatch: 0.0692525671922643
# Area: 3300.5
# Context: 0.05772726982831955
# Width: 116
# ====================
# 8
# [WindowsPath('test/0177.pdf300/1481-1104-119-36.png'), WindowsPath('test/0177.pdf300/1856-1602-122-36.png'), WindowsPath('test/0177.pdf300/1926-1108-123-37.png'), WindowsPath('test/0177.pdf300/2839-608-113-37.png'), WindowsPath('test/0177.pdf300/2872-476-126-38.png'), WindowsPath('test/0177.pdf300/290-1285-128-36.png'), WindowsPath('test/0177.pdf300/795-1593-126-35.png'), WindowsPath('test/0177.pdf300/887-1635-116-35.png')]
# 8

# %%
# Out:
# source/0177.pdf300.png
# 0177.pdf300
# test/0177.pdf300\1481-1104-119-36.png
# ContoursNum: 2
# ShapeMatch: 0.08286909725308596
# Area: 3353.5
# Context: 0.056543782353401184
# Width: 119
# ====================
# test/0177.pdf300\1856-1602-122-36.png
# ContoursNum: 2
# ShapeMatch: 0.0
# Area: 3284.0
# Context: 0.0035643407609313726
# Width: 112
# ====================
# test/0177.pdf300\1926-1108-123-37.png
# ContoursNum: 2
# ShapeMatch: 0.032133396919193515
# Area: 3215.0
# Context: 0.018148206174373627
# Width: 112
# ====================
# test/0177.pdf300\2839-608-113-37.png
# ContoursNum: 2
# ShapeMatch: 0.035609805886138116
# Area: 3252.0
# Context: 0.017955895513296127
# Width: 113
# ====================
# test/0177.pdf300\2872-476-126-38.png
# ContoursNum: 2
# ShapeMatch: 0.013304316467372635
# Area: 3358.0
# Context: 0.017506150528788567
# Width: 112
# ====================
# test/0177.pdf300\290-1285-128-36.png
# ContoursNum: 2
# ShapeMatch: 0.08014253317308455
# Area: 3303.0
# Context: 0.05758054554462433
# Width: 118
# ====================
# test/0177.pdf300\795-1593-126-35.png
# ContoursNum: 2
# ShapeMatch: 0.06127373114413902
# Area: 3276.5
# Context: 0.054037436842918396
# Width: 116
# ====================
# test/0177.pdf300\887-1635-116-35.png
# ContoursNum: 3
# ShapeMatch: 0.0692525671922643
# Area: 3300.5
# Context: 0.05772726982831955
# Width: 116
# ====================
# 8
# [WindowsPath('test/0177.pdf300/1481-1104-119-36.png'), WindowsPath('test/0177.pdf300/1856-1602-122-36.png'), WindowsPath('test/0177.pdf300/1926-1108-123-37.png'), WindowsPath('test/0177.pdf300/2839-608-113-37.png'), WindowsPath('test/0177.pdf300/2872-476-126-38.png'), WindowsPath('test/0177.pdf300/290-1285-128-36.png'), WindowsPath('test/0177.pdf300/795-1593-126-35.png'), WindowsPath('test/0177.pdf300/887-1635-116-35.png')]
# 8
