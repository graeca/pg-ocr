# %%
# %%bash
# IFS='
# '
# word='κύριος'
# sh countwords.sh $word
# files=`find  pages -type f|sort`
# for file in `echo "$files"`
# do
# echo $file
#
# cat "$file"|tr " " "\n"|sort|uniq -c|\
# sed -rn 's@'$word'@'$word'@gp'
#
#
#
# done
# Out:
# κύριος
#       6 «κύριος
#       1 «κύριος»
#       1 «κύριος»,
#       1 «κύριος».
#      32 κύριος
#       6 κύριος,
#       2 κύριος,
#       1 κύριος»
#       1 κύριος»,
#       3 κύριος·
#       4 κύριος
# pages/page 151
# pages/page 152
# pages/page 153
#       1 κύριος,
#       1 κύριος,
# pages/page 154
#       1 κύριος
# pages/page 155
# pages/page 156
# pages/page 157
# pages/page 158
#       3 κύριος
#       1 κύριος,
#       1 κύριος
# pages/page 159
# pages/page 160
# pages/page 161
# pages/page 162
#       5 κύριος
#       1 κύριος»,
# pages/page 163
# pages/page 164
#       1 κύριος
# pages/page 165
# pages/page 166
# pages/page 167
# pages/page 168
# pages/page 169
#       2 κύριος,
# pages/page 170
#       4 κύριος
# pages/page 171
#       1 κύριος,
# pages/page 172
# pages/page 173
# pages/page 174
# pages/page 175
# pages/page 176
# pages/page 177
#       2 «κύριος
#       1 «κύριος»
#       1 «κύριος»,
#       5 κύριος
#       1 κύριος»
#       2 κύριος
# ...

# %%
# %%bash
#
# file='trinitate151-195.txt'
# pages=`cat "$file"
# #|sed -rn  '/page/p'`
# #echo "$pages"
# for header in `echo "$pages"`
# do
# #echo zzz$header
# #x=`echo "$header"|sed 's@page.*@OK@g'`
# #echo "$x"
# #done
#
#
#
# :
#
#
# done
#
#
# csplit --help
#
#
#
#
#
# #cat "$file"|tr " " "\n"|sort|uniq -c
#
# #sh countwords.sh 'πνεῦμα'
# #echo "======================"
# #sh countwords.sh 'κύριος'
# Out:
# Usage: csplit [OPTION]... FILE PATTERN...
# Output pieces of FILE separated by PATTERN(s) to files 'xx00', 'xx01', ...,
# and output byte counts of each piece to standard output.
#
# Read standard input if FILE is -
#
# Mandatory arguments to long options are mandatory for short options too.
#   -b, --suffix-format=FORMAT  use sprintf FORMAT instead of %02d
#   -f, --prefix=PREFIX        use PREFIX instead of 'xx'
#   -k, --keep-files           do not remove output files on errors
#       --suppress-matched     suppress the lines matching PATTERN
#   -n, --digits=DIGITS        use specified number of digits instead of 2
#   -s, --quiet, --silent      do not print counts of output file sizes
#   -z, --elide-empty-files    remove empty output files
#       --help     display this help and exit
#       --version  output version information and exit
#
# Each PATTERN may be:
#   INTEGER            copy up to but not including specified line number
# ...

# %%
# %%bash
# words='∆αυῒδ
# Ῥωμαίοις
# ὑποστάσεως
# πίστεως
# ἅγιον
# Κορινθίοις
# φῶς
# Ἰησοῦ
# Χριστοῦ
# Παῦλος
# πατρὸς
# υἱὸς
# θεὸν
# κύριος
# πνεύματος
# πνεῦμα
# θεὸς
# ὅτι
# γὰρ
# καὶ'
#
# #echo $words
#
# for word in `echo "$words"`
# do
# echo $word
# echo '-------------------------'
# sh countwords.sh "$word"
# done
# Out:
# ∆αυῒδ
# -------------------------
# Ῥωμαίοις
# -------------------------
# ὑποστάσεως
# -------------------------
# πίστεως
# -------------------------
# ἅγιον
# -------------------------
# Κορινθίοις
# -------------------------
# φῶς
# -------------------------
# Ἰησοῦ
# -------------------------
# Χριστοῦ
# -------------------------
# Παῦλος
# -------------------------
# πατρὸς
# -------------------------
# υἱὸς
# -------------------------
# θεὸν
# -------------------------
# κύριος
# -------------------------
# πνεύματος
# -------------------------
# πνεῦμα
# -------------------------
# θεὸς
# -------------------------
# ὅτι
# -------------------------
# γὰρ
# -------------------------
# καὶ
# -------------------------
# : not found
# : not found
# : not found
# : not found
# : not found
# : not found
# : not found
# : not found
# cat: 'trinitate151-195.txt'$'\r': No such file or directory
# : not found
# sed: -e expression #1, char 33: unknown option to `s'
# : not found
# ...

# %%
# %%bash
# csplit -z trinitate151-195.txt /page/ {*}
# Out:
# 2800
# 2456
# 2685
# 1375
# 2882
# 3338
# 2094
# 3879
# 4361
# 3201
# 4214
# 4104
# 2339
# 3118
# 1972
# 3390
# 2973
# 1291
# 4628
# 3874
# 4411
# 4103
# 4452
# 5205
# 2133
# 2235
# 5270
# 1480
# 4619
# 3301
# 3018
# 2488
# 3770
# 3140
# 2666
# 2848
# 3648
# 3852
# 4257
# 4364
# 3102
# 2444
# 3251
# 4772
# 3819

# %%
# %%bash
# files=`find  pages -type f|sort`
# for file in `echo "$files"`
# do
#
# name=`cat "$file"|sed -rn /page.*/p`
# echo $file
# echo pages/$name
#
# #mv "$file" "$name"
# done
# Out:
# pages/xx00
# pages/page 151
# pages/xx01
# pages/page 152
# pages/xx02
# pages/page 153
# pages/xx03
# pages/page 154
# pages/xx04
# pages/page 155
# pages/xx05
# pages/page 156
# pages/xx06
# pages/page 157
# pages/xx07
# pages/page 158
# pages/xx08
# pages/page 159
# pages/xx09
# pages/page 160
# pages/xx10
# pages/page 161
# pages/xx11
# pages/page 162
# pages/xx12
# pages/page 163
# pages/xx13
# pages/page 164
# pages/xx14
# pages/page 165
# pages/xx15
# pages/page 166
# pages/xx16
# pages/page 167
# pages/xx17
# pages/page 168
# pages/xx18
# pages/page 169
# pages/xx19
# pages/page 170
# pages/xx20
# pages/page 171
# pages/xx21
# pages/page 172
# pages/xx22
# pages/page 173
# pages/xx23
# pages/page 174
# pages/xx24
# pages/page 175
# pages/xx25
# pages/page 176
# pages/xx26
# pages/page 177
# pages/xx27
# pages/page 178
# pages/xx28
# pages/page 179
# pages/xx29
# pages/page 180
# pages/xx30
# pages/page 181
# pages/xx31
# pages/page 182
# pages/xx32
# pages/page 183
# ...

# %%
# %%bash
# IFS='
# '
# word='κύριος'
# files=`find  pages -type f|sort`
# for file in `echo "$files"`
# do
# echo $file
#
# cat "$file"|tr " " "\n"|sort|uniq -c|\
# sed -rn 's@'$word'@'$word'@gp'
#
#
#
# done
# Out:
# pages/page 151
# pages/page 152
# pages/page 153
#       1 κύριος,
#       1 κύριος,
# pages/page 154
#       1 κύριος
# pages/page 155
# pages/page 156
# pages/page 157
# pages/page 158
#       3 κύριος
#       1 κύριος,
#       1 κύριος
# pages/page 159
# pages/page 160
# pages/page 161
# pages/page 162
#       5 κύριος
#       1 κύριος»,
# pages/page 163
# pages/page 164
#       1 κύριος
# pages/page 165
# pages/page 166
# pages/page 167
# pages/page 168
# pages/page 169
#       2 κύριος,
# pages/page 170
#       4 κύριος
# pages/page 171
#       1 κύριος,
# pages/page 172
# pages/page 173
# pages/page 174
# pages/page 175
# pages/page 176
# pages/page 177
#       2 «κύριος
#       1 «κύριος»
#       1 «κύριος»,
#       5 κύριος
#       1 κύριος»
#       2 κύριος
# pages/page 178
#       1 «κύριος».
#       1 κύριος·
# pages/page 179
# pages/page 18
#       1 κύριος
# pages/page 180
#       1 κύριος,
# pages/page 181
# pages/page 182
#       1 «κύριος
#       1 κύριος
# ...
